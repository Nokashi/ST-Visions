# %%
import os, sys
import pandas as pd
import geopandas as gpd
import shapely
import numpy as np
from kafka import KafkaProducer
import json
import time
import bokeh.models as bokeh_models

sys.path.append(os.path.abspath('../../src')) # Ideally ST_Visions will be installed as a module, therefore this is more of a development setting for quick testing.

from st_visions.visualization.st_visualizer import st_visualizer
from st_visions.streaming.st_vizstream import ST_KafkaStream

# %load_ext autoreload
# %autoreload 2
os.environ["BOKEH_ALLOW_WS_ORIGIN"] = "*" # DEV ENVIROMENT BANDAID FOR VSCODE VISUALIZATIONS, will be edited

# %%
def simulate_kafka_stream(
    csv_path,
    topic="test_topic",
    bootstrap_servers="localhost:9092",
    key_field=None,
    delay=0.5
):
    df = pd.read_csv(csv_path).head(30)
    print(f"Loaded CSV: {len(df)} rows. Streaming to '{topic}'...")

    producer = KafkaProducer(
        bootstrap_servers=bootstrap_servers,
        value_serializer=lambda v: json.dumps(v).encode("utf-8"),
    )

    records = df.to_dict(orient="records")  #TODO: orient(list)
    for record in records:
        producer.send(topic, value=record)
        print(f"[KAFKA PRODUCER] Sending the following:  {record}")
        producer.flush()
        time.sleep(delay) 

    producer.close()
    print("Test stream finalized")

# %%
st_viz = st_visualizer(limit=5000) # Initialize a VISIONS Instance (ST Visualizer Object)

# %%
stream = ST_KafkaStream(topic_name='st-viz-topic')
# Out:
# Topic 'st-viz-topic' exists.
# Stream thread initialized
# Connected to stream successfully!
# ---------------------------------
# Listening to topic 'st-viz-topic'...

# %%
simulate_kafka_stream(r'..\..\data\unipi_ais_dynamic_2017\unipi_ais_dynamic_dec2017.csv', 'st-viz-topic')
# Out:
# Loaded CSV: 30 rows. Streaming to 'st-viz-topic'...
# [KAFKA PRODUCER] Sending the following:  {'t': 1512132540000, 'vessel_id': '7517504dc74ad38fd05748602a97e112f19a54bbb36cd764e6a463f9abe8f018', 'lon': 23.5557483333333, 'lat': 37.963016666666704, 'heading': nan, 'speed': 4.6, 'course': 211.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512132540000, 'vessel_id': '698b77dbaed14cc7fe67ee1e5017095b904643454fde596c1ec902c404aa100c', 'lon': 23.62548166666669, 'lat': 37.9407766666667, 'heading': 153.0, 'speed': 0.0, 'course': 0.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512132541000, 'vessel_id': '11e59aaa59860630711db1173860c9b322292d9da5a3311c469093a8d754c058', 'lon': 23.640975, 'lat': 37.9448533333333, 'heading': nan, 'speed': 0.1, 'course': 304.9}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512132542000, 'vessel_id': 'aa42d53ba2d4bd0cc50cb096190a4312347569661f629b4f1f4f897d48534f8d', 'lon': 23.6386733333333, 'lat': 37.947715, 'heading': 179.0, 'speed': 0.0, 'course': 0.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512132542000, 'vessel_id': 'a015e450adebfb22475defe51ff634e536ace35927b274fabe027f5114b8e9c2', 'lon': 23.586633333333307, 'lat': 37.8268666666667, 'heading': 205.0, 'speed': 3.4, 'course': 221.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079204000, 'vessel_id': '7b318894698439a7afea03e1a16427f7a9dce450b3aac3d536a1756547200d74', 'lon': 23.680755, 'lat': 37.93104500000001, 'heading': 61.0, 'speed': 0.0, 'course': 8.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512

# [KAFKA PRODUCER] Sending the following:  {'t': 1512079208000, 'vessel_id': '6f7fbebb26c97cca4f6f6b6a4a2a15a449fa765c934bfb59fea8a1ee211ae046', 'lon': 23.64985, 'lat': 37.936643333333286, 'heading': nan, 'speed': 0.0, 'course': 320.1}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079209000, 'vessel_id': '05edaaf038e80b4952faf8ea6ee12f2e95066896dc0bc91fdaea37c49124685a', 'lon': 23.551945, 'lat': 38.035638333333296, 'heading': nan, 'speed': 0.0, 'course': 0.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079209000, 'vessel_id': '46fabfff0d2b5de2a9db5bac2236739e08cb4ccb83b7c9dd90047c82e5df2a6b', 'lon': 23.587595, 'lat': 37.875235, 'heading': 197.0, 'speed': 3.5, 'course': 185.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079209000, 'vessel_id': '8e75c1624d2d78c0f3df3598aaa14f5fcfe6252557fb7b3f8b0426d1f5d5edbc', 'lon': 23.58376666666669, 'lat': 37.952783333333294, 'heading': 274.0, 'speed': 0.1, 'course': 264.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079209000, 'vessel_id': '1d2a32243707b28cb49a7c7806585b884d7f84b30c1a248eda6636f67780f0a4', 'lon': 23.6385, 'lat': 37.9443333333333, 'heading': 215.0, 'speed': 0.0, 'course': 113.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079209000, 'vessel_id': '17a2772f901d45b69647ab7ed764ba82c5028da1c59480bda6eca2bce640c27c', 'lon': 23.6345, 'lat': 37.94300000000001, 'heading': 37.0, 'speed': 0.0, 'course': 286.0}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079210000, 'vessel_id': 'af8ab01cfe8ab02333ec5f7689f6711501246324b7d5d7fcf4e0391192860e2b', 'lon': 23.6487, 'lat': 37.93325, 'heading': 135.0, 'speed': 0.0, 'course': nan}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079210000, 'vessel_id': 'da8ce411f6eb032f235332e1ece0dc61e8022bf8e18cebc06de9879e97f1f8c2', 'lon': 23.571465, 'lat': 37.9606366666667, 'heading': nan, 'speed': 0.1, 'course': 89.3}
# [KAFKA PRODUCER] Sending the following:  {'t': 1512079210000, 'vessel_id': '930c19ded7f132180f82c7e32cd55e5d3708fb1e969bed2c5db7b506d7e604ab', 'lon': 23.6412816666667, 'lat': 37.94787, 'heading': 181.0, 'speed': 0.0, 'course': 283.4}
# Test stream finalized

# %%
st_viz.get_data_stream(stream)

# %%
st_viz.create_canvas(title=f'Prototype Plot', tile_provider="CARTODBPOSITRON", sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

# %%
circ = st_viz.add_marker(marker='circle', size=10, color='royalblue', alpha=0.7, fill_alpha=0.5, muted_alpha=0, legend_label=f'Vessel GPS Locations')

# %%
st_viz.add_lasso_select()

st_viz.figure.legend.location = "top_left"
st_viz.figure.legend.click_policy = "mute"
st_viz.figure.toolbar.active_scroll = st_viz.figure.select_one(bokeh_models.WheelZoomTool)

# %%
st_viz.show_figures(notebook=True, height=300, width=300, sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e630e23f-33c8-4105-bb33-0bf078501d39">Loading BokehJS ...</span>
#     </div>
# <script id="f17379d0-cacd-47dd-916a-9fc382ceccc2">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:55193/autoload.js?bokeh-autoload-element=f17379d0-cacd-47dd-916a-9fc382ceccc2&bokeh-absolute-url=http://localhost:55193&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
stream.stop()
# Out:
# Stopping stream...
# Stream stopped
