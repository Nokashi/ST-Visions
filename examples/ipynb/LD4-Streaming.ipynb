# %% [markdown]
# # ST_Visions Live Demo 4: Real Time Streaming
#
# One of the core features of the ST-Visions update is the addition of real-time streaming capabilities. In the following demo, a data stream of Vessel AIS Position records is being received by the library, and we're visualizing this information on an interactive bokeh plot that updates dynamically as new data arrives.
#
# In this demo, we are working with a Kafka Data stream, but the architechture of the library enables easy extention for other data streaming pipeline options
#
#
# ## **NOTE**
#
# As of 01/2026, notebook data streaming using ST-Visions doesnt work in visual studio code. Using a jupyter notebook/jupyterlab local server is recommended for the intended results of the demo
#
#
# ## Importing Necessary Libraries/Modules

# %%
import os, sys
from dotenv import load_dotenv
load_dotenv("..\.env")
env = os.environ
import bokeh.models as bokeh_models
import pyarrow as pa
sys.path.append(os.path.abspath('../../src')) # Ideally ST_Visions will be installed as a module, therefore this is more of a development setting for quick testing.
from visualization.st_visualizer import st_visualizer
from streaming.st_vizstream import ST_KafkaStream

# %load_ext autoreload
# %autoreload 2
os.environ["BOKEH_ALLOW_WS_ORIGIN"] = "*"

# %% [markdown]
# Internally, the library uses pyarrow to handle the batches of data that are being received in real time depending on the limit given to the VISIONS Instance object. Additionally, in order to provide persistance over the available data in the VISIONS instance at any given moment, a pyarrow data structure is used.
#
# That being said, the VISIONS Instance expects a Pyarrow Schema to be provided that maps to the columns that we are expecting every record of the data stream to have. This is used to safely initialize the CDS during canvas generation and to properly prepare the VISIONS instance to receive the streamed data

# %%
expected_schema = pa.schema([
    ("lon", pa.float64()),
    ("lat", pa.float64()),
    ("vessel_id", pa.int64()),
    ("speed", pa.float32()),
    ("course", pa.float32()),
    ("heading", pa.float32()),
    ("t", pa.timestamp('ms'))
])

# %% [markdown]
# Create a VISIONS Instance, then initialize a canvas and a marker for the incoming data stream

# %%
st_viz = st_visualizer(limit=5000, expected_schema=expected_schema) # Initialize a VISIONS Instance (ST Visualizer Object)
st_viz.create_canvas(title=f'Showing Streaming Data', tile_provider="CARTODBPOSITRON", sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")
circ = st_viz.add_marker(marker='circle', size=10, color='royalblue', alpha=0.7, fill_alpha=0.5, muted_alpha=0, legend_label=f'Vessel GPS Locations')

# %% [markdown]
# Establish connection to Kafka using an `ST_KafkaStream` instance. The class handles all connection and serialization logic.
#
# Using `get_data_stream` and passing over the stream instance, we hook into our preferred kafka topic

# %%
stream = ST_KafkaStream(topic_name='st-viz-topic')
st_viz.get_data_stream(stream=stream, notebook=True, refresh_rate=250)

# %%
tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), ('Coordinates','(@lon_merc, @lat_merc)')]

st_viz.add_hover_tooltips(tooltips)
st_viz.add_lasso_select()

st_viz.figure.legend.location = "top_left"
st_viz.figure.legend.click_policy = "mute"
st_viz.figure.toolbar.active_scroll = st_viz.figure.select_one(bokeh_models.WheelZoomTool)

# %%
st_viz.show_figures(notebook=True, height=300, width=300, live=True, sizing_mode='stretch_both')

# %% [markdown]
# ## *Note*: For additional Streaming Use cases such as filters interacting with a live data feed, refer to the respective python examples
