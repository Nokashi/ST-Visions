# %% [markdown]
# # Importing Essential Libraries

# %%
import os, sys
from dotenv import load_dotenv
load_dotenv("..\.env")
env = os.environ

# %load_ext autoreload
# %autoreload 2


import pandas as pd
import geopandas as gpd
import shapely
import numpy as np
import bokeh.models as bkhm
import bokeh.colors as bokeh_colors
from loguru import logger

sys.path.append(os.path.abspath('../../src')) # Ideally ST_Visions will be installed as a module, therefore this is more of a development setting for quick testing.

from visualization.st_visualizer import st_visualizer
import express.st_vizexpress as viz_express
import visualization.filter_callbacks as viz_callbacks
import visualization.geom_helper as viz_helper

os.environ["BOKEH_ALLOW_WS_ORIGIN"] = "*" # DEV ENVIROMENT BANDAID FOR VSCODE VISUALIZATIONS, will be edited

pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Defining Global Variables

# %% [markdown]
#   * ### Loading Dataset

# %%
gdf = pd.read_csv(env['CATEGORICAL_SUBSET_DEMO'])
gdf = viz_helper.create_geometry(gdf, source_crs=4326)
bbox = gdf.total_bounds
west, south, east, north = bbox


bbox_polygon = shapely.geometry.box(west, south, east, north)
spatial_coverage = gpd.GeoDataFrame(geometry=[bbox_polygon], crs=gdf.crs)
width = (east - west) / 24
cut_result = viz_helper.quadrat_cut_geometry(bbox_polygon, width, min_num=24)

spatial_coverage_cut = gpd.GeoDataFrame(
    geometry=list(cut_result.geoms) if hasattr(cut_result, 'geoms') else [cut_result],
    crs=4326
)

# %% [markdown]
#   * ### Creating Choropleth (Grid) Geometry
#
#   We get the borderbox of an existing GeoDataFrame, then use shapely to create a Polygon covering the box (a square essentially)

# %% [markdown]
#   * ### Classifying Area Proximity (i.e., Populate the Choropleth Map)

# %%
classified_gdf = viz_helper.classify_area_proximity(gdf.copy(), spatial_coverage_cut, compensate=True, verbose=True)

cnt = classified_gdf['area_id'].value_counts()

spatial_coverage_cut = spatial_coverage_cut.copy() 
spatial_coverage_cut['count'] = 0 
spatial_coverage_cut.loc[cnt.index, 'count'] = cnt.values

if spatial_coverage_cut.geometry.name != 'geometry':
    spatial_coverage_cut = spatial_coverage_cut.rename_geometry('geometry')

spatial_coverage_cut = spatial_coverage_cut[spatial_coverage_cut['count'] > 0]
# Out:
# 2026-03-15 23:55:48.639 | INFO     | visualization.geom_helper:classify_area_proximity:247 - Creating spatial index for points...
# 2026-03-15 23:55:48.652 | INFO     | visualization.geom_helper:classify_area_proximity:252 - Classifying spatial proximity...
# 552it [00:00, 1852.35it/s]

# %% [markdown]
# # 1. Simple Choropleth Map

# %%
st_viz = st_visualizer(limit=len(spatial_coverage_cut))
st_viz.set_data(spatial_coverage_cut.dropna())

st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

st_viz.add_numerical_colormap('Viridis256', 'count', colorbar=True, cb_orientation='vertical', cb_location='right', label_standoff=12, border_line_color=None, location=(0,0))
st_viz.add_polygon(fill_color=st_viz.cmap, line_color=st_viz.cmap, fill_alpha=0.6, muted_alpha=0, legend_label=f'GPS Locations (Choropleth Map)')

st_viz.figure.legend.location = "top_left"
st_viz.figure.legend.click_policy = "mute"
st_viz.figure.toolbar.active_scroll = st_viz.figure.select_one(bkhm.WheelZoomTool)
# Out:
# 2026-03-15 23:55:50.425 | INFO     | visualization.st_visualizer:__init__:92 - VISIONS instance initialized with limit=121, target_crs=3857

# %%
st_viz.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a9ad4b89-33a9-4dd0-81d0-80e0d2d264d5">Loading BokehJS ...</span>
#     </div>
# <script id="df34a4f3-6fe2-44a2-8cfb-fb8eff72b854">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:49329/autoload.js?bokeh-autoload-element=df34a4f3-6fe2-44a2-8cfb-fb8eff72b854&bokeh-absolute-url=http://localhost:49329&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %% [markdown]
# # 2. (Advanced) Integrating Filters to Choropleth Map

# %%
st_viz = st_visualizer(limit=len(spatial_coverage_cut))
st_viz.set_data(spatial_coverage_cut)

st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', 
                     height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

st_viz.add_numerical_colormap('Viridis256', 'count', colorbar=True, 
                              cb_orientation='vertical', cb_location='right', 
                              label_standoff=12, border_line_color=None, 
                              location=(0,0), nan_color=bokeh_colors.RGB(1,1,1,0))
st_viz.add_polygon(fill_color=st_viz.cmap, line_color=st_viz.cmap, 
                   fill_alpha=0.6, muted_alpha=0, 
                   legend_label=f'GPS Locations (Choropleth)')

data_points = st_visualizer(limit=len(gdf))
data_points.set_data(gdf)
data_points.set_figure(st_viz.figure)


categorical_name = 'vessel_type'

class Callback(viz_callbacks.ST_BokehFilters):
    def __init__(self, vsn_instance, widget):
        super().__init__(vsn_instance, widget)

    def callback_prepare_data(self, new_pts):
        cnt = viz_helper.classify_area_proximity(
            new_pts,
            st_viz.data,
            buffer_amount=1e-6,
            compensate=True,
            verbose=True
        ).area_id.value_counts()

        if cnt.empty:
            print("No matches found")
            return

        st_viz.canvas_data = st_viz.data.loc[cnt.index].copy()
        st_viz.canvas_data['count'] = cnt.values
        st_viz.canvas_data = st_viz.prepare_data(st_viz.canvas_data)

        low, high = st_viz.canvas_data[st_viz.cmap['field']].agg(["min", "max"])
        st_viz.cmap['transform'].low = 0 if low == high else low
        st_viz.cmap['transform'].high = high

        st_viz.source.data = st_viz.canvas_data.drop(
            st_viz.canvas_data.geometry.name, axis=1
        ).to_dict(orient="list")

    def callback(self, attr, old, new):
        if self.vsn_instance.data is None or self.vsn_instance.data.empty:
            return  # skip
        

        self.callback_filter_data()
        full_data = self.get_data()
        filtered_data = self.vsn_instance.apply_active_filters(full_data)

        print(f"filtered_data sample: {filtered_data.geometry.iloc[0]}")
        
        self.callback_prepare_data(filtered_data)

data_points.add_categorical_filter(
    title='Vessel Type', 
    categorical_name=categorical_name, 
    height_policy='min', 
    callback_class=Callback
)
# Out:
# 2026-03-15 23:56:09.814 | INFO     | visualization.st_visualizer:__init__:92 - VISIONS instance initialized with limit=121, target_crs=3857
# 2026-03-15 23:56:09.850 | INFO     | visualization.st_visualizer:__init__:92 - VISIONS instance initialized with limit=50000, target_crs=3857
# Select(id='p10176', ...)

# %%
class Callback(viz_callbacks.ST_BokehFilters):
    def __init__(self, vsn_instance, widget):
        super().__init__(vsn_instance, widget)

    def callback_prepare_data(self, new_pts):
        try:
            cnt = viz_helper.classify_area_proximity(
                new_pts,
                st_viz.data,
                buffer_amount=1e-6,
                compensate=True,
                verbose=True
            ).area_id.value_counts()

            if cnt.empty:
                print("No matches found")
                return

            st_viz.canvas_data = st_viz.data.loc[cnt.index].copy()
            st_viz.canvas_data['count'] = cnt.values
            st_viz.canvas_data = st_viz.prepare_data(st_viz.canvas_data)

            low, high = st_viz.canvas_data[st_viz.cmap['field']].agg(["min", "max"])
            st_viz.cmap['transform'].low = 0 if low == high else low
            st_viz.cmap['transform'].high = high

            st_viz.source.data = st_viz.canvas_data.drop(
                st_viz.canvas_data.geometry.name, axis=1
            ).to_dict(orient="list")

        except Exception as e:
            import traceback
            print(f"ERROR in callback_prepare_data: {e}")
            traceback.print_exc()

    def callback(self, attr, old, new):
        self.callback_filter_data()

        cat_value = self.widget.value
        new_pts = self.get_data()

        if cat_value:
            new_pts = new_pts.loc[new_pts[categorical_name] == cat_value].copy()

        self.callback_prepare_data(new_pts)

data_points.add_categorical_filter(
    title='Vessel Type', 
    categorical_name=categorical_name, 
    height_policy='min', 
    callback_class=Callback
)

# %%
data_points.figure.legend.location = "top_left"
data_points.figure.legend.click_policy = "mute"
data_points.figure.toolbar.active_scroll = data_points.figure.select_one(bkhm.WheelZoomTool)

# %%
data_points.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d80e4a45-3a27-4c91-93fe-f5918f0444de">Loading BokehJS ...</span>
#     </div>
# <script id="b04f3314-3ae6-4301-9a99-0862667e85ca">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:49358/autoload.js?bokeh-autoload-element=b04f3314-3ae6-4301-9a99-0862667e85ca&bokeh-absolute-url=http://localhost:49358&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# 2026-03-15 23:56:16.018 | INFO     | visualization.geom_helper:classify_area_proximity:247 - Creating spatial index for points...
# 2026-03-15 23:56:16.019 | INFO     | visualization.geom_helper:classify_area_proximity:252 - Classifying spatial proximity...
# filtered_data sample: POINT (2626734.4087098027 4573269.130661293)
# st_viz.data sample: POLYGON ((2595745.7990803164 4572850.0621821135, 2598961.587247297 4572850.0621821135, 2598961.587247297 4570527.02167724, 2595745.7990803164 4570527.02167724, 2595745.7990803164 4572850.0621821135))
# 7it [00:00, 3498.17it/s]
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' content: {'events': [{'kind': 'ModelChanged', 'model': {'id': 'p10176'}, 'attr': 'value', 'new': 'Cargo, Hazardous category B'}]}
#  error: KeyError("None of [Index([106], dtype='int64')] are in the [index]")
# Traceback (most recent call last):
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\server\protocol_handler.py", line 94, in handle
#     work = await handler(message, connection)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\server\session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\server\session.py", line 286, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 104, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py", line 453, in invoke_with_curdoc
#     return f()
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 104, in <lambda>
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\document.py", line 401, in apply_json_patch
#     DocumentPatchedEvent.handle_event(self, event, setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\events.py", line 244, in handle_event
#     event_cls._handle_event(doc, event)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\events.py", line 376, in _handle_event
#     model.set_from_json(attr, value, setter=event.setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\has_props.py", line 449, in set_from_json
#     descriptor.set_from_json(self, value, setter=setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\descriptors.py", line 420, in set_from_json
#     self._set(obj, old, value, setter=setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\descriptors.py", line 614, in _set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\descriptors.py", line 692, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\model\model.py", line 583, in trigger
#     super().trigger(descriptor.name, old, new, hint=hint, setter=setter)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\util\callback_manager.py", line 177, in trigger
#     self.document.callbacks.notify_change(cast(Model, self), attr, old, new, hint, setter, invoke)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py", line 251, in notify_change
#     self.trigger_on_change(event)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py", line 418, in trigger_on_change
#     invoke_with_curdoc(doc, event.callback_invoker)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py", line 453, in invoke_with_curdoc
#     return f()
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\util\callback_manager.py", line 174, in invoke
#     callback(attr, old, new)
#   File "C:\Users\Nokashi\AppData\Local\Temp\ipykernel_9384\2556371447.py", line 63, in callback
#     self.callback_prepare_data(filtered_data)
#   File "C:\Users\Nokashi\AppData\Local\Temp\ipykernel_9384\2556371447.py", line 27, in callback_prepare_data
#     cnt = viz_helper.classify_area_proximity(
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\src\visualization\geom_helper.py", line 263, in classify_area_proximity
#     matched = trajectories.loc[possible_matches]
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\pandas\core\indexing.py", line 1192, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\pandas\core\indexing.py", line 1421, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\pandas\core\indexing.py", line 1361, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\pandas\core\indexing.py", line 1559, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\pandas\core\indexes\base.py", line 6212, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\pandas\core\indexes\base.py", line 6261, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index([106], dtype='int64')] are in the [index]"

# %% [markdown]
# ### Create a VISIONS instance for the Choropleth plot (main canvas)

# %%
st_viz = st_visualizer(limit=len(spatial_coverage_cut))
st_viz.set_data(spatial_coverage_cut)

st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

st_viz.add_numerical_colormap('Viridis256', 'count', colorbar=True, cb_orientation='vertical', cb_location='right', label_standoff=12, border_line_color=None, location=(0,0), nan_color=bokeh_colors.RGB(1,1,1,0))
st_viz.add_polygon(fill_color=st_viz.cmap, line_color=st_viz.cmap, fill_alpha=0.6, muted_alpha=0, legend_label=f'GPS Locations (Choropleth)')

# %%
data_points = st_visualizer(limit=len(gdf))
data_points.set_data(gdf)
data_points.set_figure(st_viz.figure)


categorical_name='vessel_type'

# %% [markdown]
# ### Create a VISIONS instance for keeping (& filtering) the original data

# %%
data_points = st_visualizer(limit=len(gdf))
data_points.set_data(gdf)
data_points.set_figure(st_viz.figure)


categorical_name='vessel_type'

class Callback(viz_callbacks.ST_BokehFilters):
    def __init__(self, vsn_instance, widget):
        super().__init__(vsn_instance, widget)

    def callback_prepare_data(self, new_pts):
        cnt = viz_helper.classify_area_proximity(
            new_pts,
            st_viz.data,
            compensate=True,
            verbose=True
        ).area_id.value_counts()

        if cnt.empty:
            print("No matches found")
            return

        # Port from old logic — select only rows with counts, index alignment guaranteed
        st_viz.canvas_data = st_viz.data.loc[cnt.index].copy()
        st_viz.canvas_data['count'] = cnt.values

        st_viz.canvas_data = st_viz.prepare_data(st_viz.canvas_data)

        low, high = st_viz.canvas_data[st_viz.cmap['field']].agg(["min", "max"])
        st_viz.cmap['transform'].low = 0 if low == high else low
        st_viz.cmap['transform'].high = high

        st_viz.source.data = st_viz.canvas_data.drop(
            st_viz.canvas_data.geometry.name, axis=1
        ).to_dict(orient="list")

    def callback(self, attr, old, new):
        self.callback_filter_data()

        cat_value = self.widget.value
        new_pts = self.get_data()

        if cat_value:
            new_pts = new_pts.loc[new_pts[categorical_name] == cat_value].copy()

        self.callback_prepare_data(new_pts)

data_points.add_categorical_filter(
    title='Vessel Type', 
    categorical_name=categorical_name, 
    height_policy='min', 
    callback_class=Callback
)


        
data_points.add_categorical_filter(title='Vessel Type', categorical_name=categorical_name, height_policy='min', callback_class=Callback)

# %% [markdown]
# ### Camera, Lights, Action

# %%
data_points.figure.legend.location = "top_left"
data_points.figure.legend.click_policy = "mute"
data_points.figure.toolbar.active_scroll = data_points.figure.select_one(bkhm.WheelZoomTool)

# %%
data_points.show_figures(notebook=True, sizing_mode='stretch_both')

# %% [markdown]
# # 3. Plot Multiple Datasets at the Same Canvas

# %%
st_viz = st_visualizer(limit=500)
st_viz.get_data_csv(env['SARONIC_GULF_AIS'], nrows=1000)
st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")
st_viz.add_marker(marker='circle', size=10, color='royalblue', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations A')
st_viz.add_hover_tooltips(tooltips = [('Vessel ID','@vessel_id'), ('Coordinates','(@lon, @lat)')], renderers=st_viz.renderers)

st_viz2 = st_visualizer(limit=500)
st_viz2.get_data_csv(env['CATEGORICAL_SUBSET_DEMO'], nrows=1000)
st_viz2.set_figure(st_viz.figure)
st_viz2.create_source()
st_viz2.add_marker(marker='triangle', size=10, color='red', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations B')
st_viz2.add_hover_tooltips(tooltips = [('Vessel ID','@vessel_id'), ('Coordinates','(@lon, @lat)')], renderers=st_viz2.renderers)

st_viz2.figure.legend.location = "top_left"
st_viz2.figure.legend.click_policy = "mute"
st_viz2.figure.toolbar.active_scroll = st_viz2.figure.select_one(bkhm.WheelZoomTool)
st_viz2.show_figures(notebook=True, sizing_mode='stretch_both')

# %% [markdown]
# # Plot Multiple Datasets at Grid

# %%
st_viz = st_visualizer(limit=1000)
st_viz.get_data_csv(env['SARONIC_GULF_AIS'], nrows=10000)
tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), ('Coordinates','(@lon, @lat)')]
viz_express.plot_points_on_map(st_viz, tools=['lasso_select'], tooltips=tooltips)



st_viz2 = st_visualizer(limit=1000)
st_viz2.get_data_csv(env['CATEGORICAL_SUBSET_DEMO'], nrows=10000)
tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), ('Coordinates','(@lon, @lat)')]
viz_express.plot_points_on_map(st_viz2, tools=['lasso_select'], tooltips=tooltips, marker='triangle', color='red')


st_viz2.figure.legend.location = "top_left"
st_viz2.figure.legend.click_policy = "mute"
st_viz2.figure.toolbar.active_scroll = st_viz2.figure.select_one(bkhm.WheelZoomTool)


st_viz2.show_figures(figures=[st_viz.figure, st_viz2.figure], ncols=2,  notebook=True, merge_tools=True, toolbar_location='right', sizing_mode='stretch_both')

# %% [markdown]
# # Visualize Data with Map alongside DataFrame

# %%
data_points = st_visualizer(limit=5000) # Initialize a VISIONS Instance (ST Visualizer Object)
data_points.get_data_csv(filepath=env['SARONIC_GULF_AIS'], nrows=10000)


tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), 
            ('Coordinates','(@lon, @lat)')]

data_points.create_canvas(title=f'Simple Visualization', tile_provider="CARTODBPOSITRON", sizing_mode='stretch_both', height=1000, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")
circ = data_points.add_marker(marker='circle', size=10, color='royalblue', alpha=0.7, fill_alpha=0.5, muted_alpha=0, legend_label=f'Vessel GPS Locations')
data_points.add_hover_tooltips(tooltips)
data_points.add_lasso_select()


columns = [
        bkhm.TableColumn(field="t", title="Timestamp"),
        bkhm.TableColumn(field="vessel_id", title="Vessel ID"),
        bkhm.TableColumn(field="speed", title="Speed (knots)"),
        bkhm.TableColumn(field="heading", title="Heading"),
        bkhm.TableColumn(field="lon", title="Longitude"),
        bkhm.TableColumn(field="lat", title="Latitude"),
        bkhm.TableColumn(field="velocity", title="Velocity"),
        bkhm.TableColumn(field="course", title="COG")
]
data_table = bkhm.DataTable(source=data_points.source, columns=columns, width=400, height=280, sizing_mode='stretch_width')
#data_table = bkhm.DataTable(source=data_points.source, columns=columns, width=400, height=400, sizing_mode='stretch_both')


### Camera, Lights, Action
data_points.figure.legend.location = "top_left"
data_points.figure.legend.click_policy = "mute"
data_points.figure.toolbar.active_scroll = data_points.figure.select_one(bkhm.WheelZoomTool)


#data_points.show_figures([[data_points.figure, data_table], [None, None]], notebook=True)

data_points.show_figures(
    figures=[data_points.figure, data_table],
    ncols=2,
    notebook=True,
    sizing_mode='stretch_both'
)
