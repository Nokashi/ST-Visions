# %% [markdown]
# # Importing Essential Libraries

# %%
import os, sys
from dotenv import load_dotenv
load_dotenv("..\.env")
env = os.environ

# %load_ext autoreload
# %autoreload 2


import pandas as pd
import geopandas as gpd
import shapely
import numpy as np
import bokeh.models as bkhm
import bokeh.colors as bokeh_colors

sys.path.append(os.path.abspath('../../src')) # Ideally ST_Visions will be installed as a module, therefore this is more of a development setting for quick testing.

from visualization.st_visualizer import st_visualizer
import express.st_vizexpress as viz_express
import visualization.callbacks as viz_callbacks
import visualization.geom_helper as viz_helper

os.environ["BOKEH_ALLOW_WS_ORIGIN"] = "*" # DEV ENVIROMENT BANDAID FOR VSCODE VISUALIZATIONS, will be edited

pd.set_option('display.expand_frame_repr', False)

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Defining Global Variables

# %% [markdown]
#   * ### Loading Dataset

# %%
gdf = pd.read_csv(env['CATEGORICAL_SUBSET_DEMO'])
gdf = viz_helper.create_geometry(gdf, source_crs=4326)

# %% [markdown]
#   * ### Creating Choropleth (Grid) Geometry
#
#   We get the borderbox of an existing GeoDataFrame, then use shapely to create a Polygon covering the box (a square essentially)

# %%
# get bounding box as (minx, miny, maxx, maxy)
bbox = gdf.total_bounds
west, south, east, north = bbox

polygon_corners = [
    (west, north),
    (east, north),
    (east, south),
    (west, south)
]

bbox_polygon = shapely.geometry.Polygon(polygon_corners)
cut_result = viz_helper.quadrat_cut_geometry(bbox_polygon, 0.7)

spatial_coverage_cut = gpd.GeoDataFrame(
    geometry=list(cut_result.geoms) if hasattr(cut_result, 'geoms') else [cut_result],
    crs=4326
)

# %% [markdown]
#   * ### Classifying Area Proximity (i.e., Populate the Choropleth Map)

# %%
#Classify points into spatial areas
classified_gdf = viz_helper.classify_area_proximity_bulk(gdf.copy(), spatial_coverage_cut, compensate=True, verbose=True)

# Get how many points are in each area
cnt = classified_gdf['area_id'].value_counts()

# Assign counts to spatial_coverage_cut GeoDataFram. Note: spatial_coverage_cut index should match the area_id values
spatial_coverage_cut = spatial_coverage_cut.copy() 
spatial_coverage_cut['count'] = 0 
spatial_coverage_cut.loc[cnt.index, 'count'] = cnt.values

if spatial_coverage_cut.geometry.name != 'geometry':
    spatial_coverage_cut = spatial_coverage_cut.rename_geometry('geometry')
# Out:
# 2025-12-14 23:46:37.586 | INFO     | st_visions.visualization.geom_helper:classify_area_proximity_bulk:287 - Preparing geometries...
# c:\Users\Nokashi\Desktop\Thesis\ST-Visions\src\st_visions\visualization\geom_helper.py:295: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   area_geoms = spatial_areas.geometry.buffer(buffer_amount).buffer(0).values
# 2025-12-14 23:46:37.610 | INFO     | st_visions.visualization.geom_helper:classify_area_proximity_bulk:300 - Running bulk spatial query...

# %%
import shapely
shapely.__version__
# Out:
# '2.1.2'

# %%
import geopandas as gpd
import shapely

print("Shapely:", shapely.__version__)
print("GeoPandas:", gpd.__version__)
print("use_pygeos:", gpd.options.use_pygeos)
# Out:
# Shapely: 2.1.2
# GeoPandas: 1.1.1
# use_pygeos: False

# %% [markdown]
# # 1. Simple Choropleth Map

# %%
st_viz = st_visualizer(limit=len(spatial_coverage_cut))
st_viz.set_data(spatial_coverage_cut.dropna())

st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

st_viz.add_numerical_colormap('Viridis256', 'count', colorbar=True, cb_orientation='vertical', cb_location='right', label_standoff=12, border_line_color=None, location=(0,0))
st_viz.add_polygon(fill_color=st_viz.cmap, line_color=st_viz.cmap, fill_alpha=0.6, muted_alpha=0, legend_label=f'GPS Locations (Choropleth Map)')

st_viz.figure.legend.location = "top_left"
st_viz.figure.legend.click_policy = "mute"
st_viz.figure.toolbar.active_scroll = st_viz.figure.select_one(bkhm.WheelZoomTool)

st_viz.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
# 2025-12-14 23:47:47.131 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=4, target_crs=3857
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5cad0cb-a7b2-43f6-88e6-7c5cfa60c89a">Loading BokehJS ...</span>
#     </div>
# <script id="fab2231a-266e-4eea-94ec-098a39cdd09a">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57674/autoload.js?bokeh-autoload-element=fab2231a-266e-4eea-94ec-098a39cdd09a&bokeh-absolute-url=http://localhost:57674&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %% [markdown]
# # 2. (Advanced) Integrating Filters to Choropleth Map

# %% [markdown]
# ### Create a VISIONS instance for the Choropleth plot (main canvas)

# %%
st_viz = st_visualizer(limit=len(spatial_coverage_cut))
st_viz.set_data(spatial_coverage_cut)

st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

st_viz.add_numerical_colormap('Viridis256', 'count', colorbar=True, cb_orientation='vertical', cb_location='right', label_standoff=12, border_line_color=None, location=(0,0), nan_color=bokeh_colors.RGB(1,1,1,0))
st_viz.add_polygon(fill_color=st_viz.cmap, line_color=st_viz.cmap, fill_alpha=0.6, muted_alpha=0, legend_label=f'GPS Locations (Choropleth)')
# Out:
# 2025-12-14 23:47:58.893 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=4, target_crs=3857
# GlyphRenderer(id='p1202', ...)

# %% [markdown]
# ### Create a VISIONS instance for keeping (& filtering) the original data

# %%
data_points = st_visualizer(limit=len(gdf))
data_points.set_data(gdf)
data_points.set_figure(st_viz.figure)


categorical_name='vessel_type'

class Callback(viz_callbacks.BokehFilters):
    def __init__(self, vsn_instance, widget):
        super().__init__(vsn_instance, widget)
        
        
    def callback_prepare_data(self, new_pts, ready_for_output):
        self.vsn_instance.canvas_data = new_pts

        if ready_for_output:
            cnt = viz_helper.classify_area_proximity_bulk(self.vsn_instance.canvas_data, st_viz.data, compensate=True, verbose=True).area_id.value_counts()            
            st_viz.canvas_data = st_viz.data.loc[cnt.index].copy()
            st_viz.canvas_data.loc[:, 'count'] = cnt.values               
           
            st_viz.canvas_data = st_viz.prepare_data(st_viz.canvas_data)

            low, high = st_viz.canvas_data[st_viz.cmap['field']].agg(['min', 'max'])
            st_viz.cmap['transform'].low = 0 if low == high else low
            st_viz.cmap['transform'].high = high
                    
            st_viz.source.data = st_viz.canvas_data.drop(st_viz.canvas_data.geometry.name, axis=1).to_dict(orient="list")

            # print ('Releasing Lock...')
            st_viz.canvas_data = None
            self.vsn_instance.canvas_data = None
            self.vsn_instance.aquire_canvas_data = None
        
        
    def callback(self, attr, old, new):
        self.callback_filter_data()

        cat_value = self.widget.value
        new_pts = self.get_data()

        # print (cat_value, categorical_name)
        if cat_value:
            new_pts = new_pts.loc[new_pts[categorical_name] == cat_value].copy()

        self.callback_prepare_data(new_pts, self.widget.id==self.vsn_instance.aquire_canvas_data)

        
data_points.add_categorical_filter(title='Vessel Type', categorical_name=categorical_name, height_policy='min', callback_class=Callback)
# Out:
# 2025-12-14 23:48:00.856 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=50000, target_crs=3857
# Select(id='p1209', ...)

# %% [markdown]
# ### Camera, Lights, Action

# %%
data_points.figure.legend.location = "top_left"
data_points.figure.legend.click_policy = "mute"
data_points.figure.toolbar.active_scroll = data_points.figure.select_one(bkhm.WheelZoomTool)

# %%
data_points.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cc162b83-43ba-43b2-94b0-606d73a5ed6d">Loading BokehJS ...</span>
#     </div>
# <script id="b281c87a-3ccf-4d8f-8710-faef55fce720">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57694/autoload.js?bokeh-autoload-element=b281c87a-3ccf-4d8f-8710-faef55fce720&bokeh-absolute-url=http://localhost:57694&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# 2025-12-14 23:50:12.804 | INFO     | st_visions.visualization.geom_helper:classify_area_proximity_bulk:287 - Preparing geometries...
# 2025-12-14 23:50:12.805 | INFO     | st_visions.visualization.geom_helper:classify_area_proximity_bulk:300 - Running bulk spatial query...
# 2025-12-14 23:50:16.845 | INFO     | st_visions.visualization.geom_helper:classify_area_proximity_bulk:287 - Preparing geometries...
# 2025-12-14 23:50:16.846 | INFO     | st_visions.visualization.geom_helper:classify_area_proximity_bulk:300 - Running bulk spatial query...

# %% [markdown]
# # Plot Multiple Datasets at the Same Canvas

# %%
st_viz = st_visualizer(limit=500)
st_viz.get_data_csv(env['SARONIC_GULF_AIS'], nrows=1000)
st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")
st_viz.add_marker(marker='circle', size=10, color='royalblue', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations A')
st_viz.add_hover_tooltips(tooltips = [('Vessel ID','@vessel_id'), ('Coordinates','(@lon, @lat)')], renderers=st_viz.renderers)

st_viz2 = st_visualizer(limit=500)
st_viz2.get_data_csv(env['CATEGORICAL_SUBSET_DEMO'], nrows=1000)
st_viz2.set_figure(st_viz.figure)
st_viz2.create_source()
st_viz2.add_marker(marker='triangle', size=10, color='red', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations B')
st_viz2.add_hover_tooltips(tooltips = [('Vessel ID','@vessel_id'), ('Coordinates','(@lon, @lat)')], renderers=st_viz2.renderers)

st_viz2.figure.legend.location = "top_left"
st_viz2.figure.legend.click_policy = "mute"
st_viz2.figure.toolbar.active_scroll = st_viz2.figure.select_one(bkhm.WheelZoomTool)
st_viz2.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
# 2025-12-15 00:42:06.016 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857
# 2025-12-15 00:42:06.069 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="de54dc83-c34e-47c3-b214-7f54c2e8f452">Loading BokehJS ...</span>
#     </div>
# <script id="b4716669-1eac-4222-8ae2-677653583d49">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:59382/autoload.js?bokeh-autoload-element=b4716669-1eac-4222-8ae2-677653583d49&bokeh-absolute-url=http://localhost:59382&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
df = pd.read_csv(env['SARONIC_GULF_AIS'], nrows=1000)
#df_traj = viz_helper.create_linestring_from_points(viz_helper.create_geometry(df.copy()), ['vessel_id'])

st_viz3 = st_visualizer(limit=500)
st_viz3.set_data(df)

st_viz3.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")


st_viz3.add_marker(marker='triangle', size=10, color='red', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations')
st_viz3.add_hover_tooltips(tooltips = [('Vessel ID','@vessel_id'), ('Coordinates','(@lon, @lat)')], renderers=st_viz3.renderers)
#st_viz3.add_line(line_type='multi_line', line_width=5, line_color='limegreen', alpha=0.5, muted_alpha=0, legend_label=f'Vessel Trajectories')
# Out:
# 2025-12-15 00:41:04.351 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857

# %%
df_traj = viz_helper.create_linestring_from_points(viz_helper.create_geometry(df.copy()), ['vessel_id'])

st_viz4 = st_visualizer(limit=500)
st_viz4.set_data(df_traj)

st_viz4.set_figure(st_viz3.figure)
st_viz4.create_source()

st_viz4.add_line(line_type='multi_line', line_width=5, line_color='green', alpha=0.5, muted_alpha=0, legend_label=f'Vessel Trajectories')
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\tqdm\std.py:917: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)
# 100%|██████████| 110/110 [00:00<00:00, 3853.29it/s]
# 2025-12-15 00:41:05.536 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857
# GlyphRenderer(id='p4219', ...)

# %%
st_viz4.figure.legend.location = "top_left"
st_viz4.figure.legend.click_policy = "mute"
st_viz4.figure.toolbar.active_scroll = st_viz3.figure.select_one(bkhm.WheelZoomTool)
st_viz4.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dafb1dbb-d697-47ef-bb24-d92800a7b0f0">Loading BokehJS ...</span>
#     </div>
# <script id="ab06ba04-ecc1-46f0-b2ec-3352766b0974">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:59343/autoload.js?bokeh-autoload-element=ab06ba04-ecc1-46f0-b2ec-3352766b0974&bokeh-absolute-url=http://localhost:59343&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
# Out:
# Creating LineStrings:   0%|          | 0/2 [00:00<?, ?it/s]c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\tqdm\std.py:917: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)
# Creating LineStrings: 100%|██████████| 2/2 [00:00<00:00, 1999.67it/s]
#   vessel_id                        geom
# 0         A  LINESTRING (0 0, 1 1, 2 0)
# 1         B       LINESTRING (0 0, 1 1)

# %%
df = pd.read_csv(env['SARONIC_GULF_AIS'], nrows=1000)
df.loc[:, 'datetime'] = pd.to_datetime(df.t, unit='ms')

df_algn_inter = pd.read_csv(env['SARONIC_GULF_AIS'], nrows=1000)
df_algn_inter.loc[:, 'datetime'] = pd.to_datetime(df_algn_inter.t, unit='ms')

# %%
st_viz = st_visualizer(limit=500)
st_viz.get_data_csv(df, nrows=1000)
st_viz.create_canvas(title=f'Prototype Plot', sizing_mode='scale_width', height=540, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")

st_viz.add_marker(marker='circle', size=10, color='royalblue', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations')
# st_viz.add_hover_tooltips(tooltips = [('Vessel_ID','@vessel_id'), ('Datetime','@datetime{%Y-%m-%d %H:%M:%S.%3N}'), ('Coordinates','(@lon, @lat)')], formatters={'@datetime': 'datetime'}, renderers=st_viz.renderers)
# Out:
# 2025-12-15 00:10:21.597 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857
# GlyphRenderer(id='p3485', ...)

# %%
st_viz2 = st_visualizer(limit=500)
st_viz2.set_data(df_algn_inter)

st_viz2.set_figure(st_viz.figure)
st_viz2.create_source()


st_viz2.add_marker(marker='square', size=10, color='orangered', alpha=0.5, fill_alpha=0.5, muted_alpha=0, legend_label=f'GPS Locations (interpolated - Kafka)')
st_viz2.add_hover_tooltips(tooltips = [('Vessel ID','@vessel_id'), ('Datetime','@datetime{%Y-%m-%d %H:%M:%S.%3N}'), ('Coordinates','(@lon, @lat)')], formatters={'@datetime': 'datetime'}, renderers=st_viz2.renderers)
# Out:
# 2025-12-15 00:10:23.087 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857

# %%
df_traj = viz_helper.create_linestring_from_points(viz_helper.create_geometry(df.copy()), ['vessel_id'])

st_viz3 = st_visualizer(limit=500)
st_viz3.set_data(df_traj)

st_viz3.set_figure(st_viz2.figure)
st_viz3.create_source()

st_viz3.add_line(line_type='multi_line', line_width=5, line_color='limegreen', alpha=0.5, muted_alpha=0, legend_label=f'Vessel Trajectories')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\tqdm\std.py:917: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)
# 100%|██████████| 2/2 [00:00<00:00, 666.56it/s]
# 2025-12-15 00:23:57.509 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=500, target_crs=3857
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[30], line 9
#       6 st_viz3.set_figure(st_viz2.figure)
#       7 st_viz3.create_source()
# ----> 9 st_viz3.add_line(line_type='multi_line', line_width=5, line_color='limegreen', alpha=0.5, muted_alpha=0, legend_label=f'Vessel Trajectories')
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\src\st_visions\visualization\st_visualizer.py:730, in st_visualizer.add_line(self, line_type, line_color, line_width, alpha, muted_alpha, **kwargs)
#     726     raise ValueError(f'Invalid line type.')
#     728 coordinates = [f'{col}{self.__suffix}' for col in self.sp_columns]
# --> 730 renderer = getattr(self.figure, line_type)(*coordinates, source=self.source, line_color=line_color, line_width=line_width, alpha=alpha, muted_alpha=muted_alpha, **kwargs)
#     731 self.renderers.append(renderer)
#     733 return renderer
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\plotting\_decorators.py:88, in glyph_method.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#      86 if self.coordinates is not None:
#      87     kwargs.setdefault("coordinates", self.coordinates)
# ---> 88 return create_renderer(glyphclass, self.plot, **kwargs)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\plotting\_renderer.py:133, in create_renderer(glyphclass, plot, **kwargs)
#     123 muted_glyph = make_glyph(glyphclass, kwargs, muted_visuals)
#     125 glyph_renderer = GlyphRenderer(
#     126     glyph=glyph,
#     127     nonselection_glyph=nonselection_glyph or "auto",
#    (...)
#     130     muted_glyph=muted_glyph or "auto",
#     131     **renderer_kws)
# --> 133 plot.renderers.append(glyph_renderer)
#     135 if legend_kwarg:
#     136     # It must be after the renderer is added because if it creates a new `LegendItem`,
#     137     # the referenced renderer must already be present.
#     138     update_legend(plot, legend_kwarg, legend_name, glyph_renderer)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\wrappers.py:140, in notify_owner.<locals>.wrapper(self, *args, **kwargs)
#     138 old = self._saved_copy()
#     139 result = func(self, *args, **kwargs)
# --> 140 self._notify_owners(old)
#     141 return result
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\wrappers.py:169, in PropertyValueContainer._notify_owners(self, old, hint)
#     167 def _notify_owners(self, old: Any, hint: DocumentPatchedEvent | None = None) -> None:
#     168     for (owner, descriptor) in self._owners:
# --> 169         descriptor._notify_mutated(owner, old, hint=hint)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\descriptors.py:651, in PropertyDescriptor._notify_mutated(self, obj, old, hint)
#     647 # re-validate because the contents of 'old' have changed,
#     648 # in some cases this could give us a new object for the value
#     649 value = self.property.prepare_value(obj, self.name, value, hint=hint)
# --> 651 self._set(obj, old, value, hint=hint)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\descriptors.py:614, in PropertyDescriptor._set(self, obj, old, value, hint, setter)
#     611     self._set_value(obj, value)
#     613 # for notification purposes, "old" should be the logical old
# --> 614 self._trigger(obj, old, value, hint=hint, setter=setter)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\core\property\descriptors.py:692, in PropertyDescriptor._trigger(self, obj, old, value, hint, setter)
#     655 """ Unconditionally send a change event notification for the property.
#     656
#     657 Args:
#    (...)
#     689
#     690 """
#     691 if hasattr(obj, 'trigger'):
# --> 692     obj.trigger(self.name, old, value, hint, setter)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\model\model.py:583, in Model.trigger(self, attr, old, new, hint, setter)
#     581 # chain up to invoke callbacks
#     582 descriptor = self.lookup(attr)
# --> 583 super().trigger(descriptor.name, old, new, hint=hint, setter=setter)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\util\callback_manager.py:177, in PropertyCallbackManager.trigger(self, attr, old, new, hint, setter)
#     175 if self.document is not None:
#     176     from ..model import Model
# --> 177     self.document.callbacks.notify_change(cast(Model, self), attr, old, new, hint, setter, invoke)
#     178 else:
#     179     invoke()
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py:251, in DocumentCallbackManager.notify_change(self, model, attr, old, new, hint, setter, callback_invoker)
#     247         hint.setter = setter
#     249     event = hint
# --> 251 self.trigger_on_change(event)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py:423, in DocumentCallbackManager.trigger_on_change(self, event)
#     421     for cb in self.change_callbacks():
#     422         cb(event)
# --> 423 invoke_with_curdoc(doc, invoke_callbacks)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py:453, in invoke_with_curdoc(doc, f)
#     450 curdoc: Document|UnlockedDocumentProxy = UnlockedDocumentProxy(doc) if getattr(f, "nolock", False) else doc
#     452 with patch_curdoc(curdoc):
# --> 453     return f()
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py:422, in DocumentCallbackManager.trigger_on_change.<locals>.invoke_callbacks()
#     420 def invoke_callbacks() -> None:
#     421     for cb in self.change_callbacks():
# --> 422         cb(event)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\callbacks.py:278, in DocumentCallbackManager.on_change_dispatch_to.<locals>.<lambda>(event)
#     276 def on_change_dispatch_to(self, receiver: Any) -> None:
#     277     if receiver not in self._change_callbacks:
# --> 278         self._change_callbacks[receiver] = lambda event: event.dispatch(receiver)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\events.py:352, in ModelChangedEvent.dispatch(self, receiver)
#     346 def dispatch(self, receiver: Any) -> None:
#     347     ''' Dispatch handling of this event to a receiver.
#     348
#     349     This method will invoke ``receiver._document_model_changed`` if it exists.
#     350
#     351     '''
# --> 352     super().dispatch(receiver)
#     353     if hasattr(receiver, '_document_model_changed'):
#     354         cast(DocumentModelChangedMixin, receiver)._document_model_changed(self)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\document\events.py:218, in DocumentPatchedEvent.dispatch(self, receiver)
#     216 super().dispatch(receiver)
#     217 if hasattr(receiver, '_document_patched'):
# --> 218     cast(DocumentPatchedMixin, receiver)._document_patched(self)
#
# File c:\Users\Nokashi\Desktop\Thesis\ST-Visions\.venv\lib\site-packages\bokeh\server\session.py:244, in ServerSession._document_patched(self, event)
#     241 may_suppress = event.setter is self
#     243 if self._pending_writes is None:
# --> 244     raise RuntimeError("_pending_writes should be non-None when we have a document lock, and we should have the lock when the document changes")
#     246 # TODO (havocp): our "change sync" protocol is flawed because if both
#     247 # sides change the same attribute at the same time, they will each end
#     248 # up with the state of the other and their final states will differ.
#     249 for connection in self._subscribed_connections:
#
# RuntimeError: _pending_writes should be non-None when we have a document lock, and we should have the lock when the document changes

# %%
st_viz3.figure.legend.location = "top_left"
st_viz3.figure.legend.click_policy = "mute"
st_viz3.figure.toolbar.active_scroll = st_viz3.figure.select_one(bkhm.WheelZoomTool)
st_viz3.show_figures(notebook=True, sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b1e3f182-dc14-4f6e-8146-6a7d018bf0a0">Loading BokehJS ...</span>
#     </div>
# <script id="b4bc6213-ac28-4d19-a4d4-7baa59b541d9">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:58639/autoload.js?bokeh-autoload-element=b4bc6213-ac28-4d19-a4d4-7baa59b541d9&bokeh-absolute-url=http://localhost:58639&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %% [markdown]
# # Plot Multiple Datasets at Grid

# %%
st_viz = st_visualizer(limit=1000)
st_viz.get_data_csv(env['SARONIC_GULF_AIS'], nrows=10000)

tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), ('Coordinates','(@lon, @lat)')]

viz_express.plot_points_on_map(st_viz, tools=['lasso_select'], tooltips=tooltips)
# Out:
# 2025-12-14 23:59:44.909 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=1000, target_crs=3857

# %%
st_viz2 = st_visualizer(limit=1000)
st_viz2.get_data_csv(env['CATEGORICAL_SUBSET_DEMO'], nrows=10000)

tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), ('Coordinates','(@lon, @lat)')]

viz_express.plot_points_on_map(st_viz2, tools=['lasso_select'], tooltips=tooltips, marker='triangle', color='red')
# Out:
# 2025-12-14 23:59:46.019 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=1000, target_crs=3857

# %%
st_viz2.figure.legend.location = "top_left"
st_viz2.figure.legend.click_policy = "mute"
st_viz2.figure.toolbar.active_scroll = st_viz2.figure.select_one(bkhm.WheelZoomTool)

# %%
st_viz2.show_figures(figures=[st_viz.figure, st_viz2.figure], ncols=2,  notebook=True, merge_tools=True, toolbar_location='right', sizing_mode='stretch_both')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f15941d6-f347-4869-817a-7d0e1491bc79">Loading BokehJS ...</span>
#     </div>
# <script id="e5b54383-d83f-48c0-a053-d435bc0d1b4a">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:58146/autoload.js?bokeh-autoload-element=e5b54383-d83f-48c0-a053-d435bc0d1b4a&bokeh-absolute-url=http://localhost:58146&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %% [markdown]
# # Visualize Data with Map alongside DataFrame

# %%
data_points = st_visualizer(limit=5000) # Initialize a VISIONS Instance (ST Visualizer Object)
data_points.get_data_csv(filepath=env['SARONIC_GULF_AIS'], nrows=10000)


tooltips = [('Vessel ID','@vessel_id'), ('Timestamp','@t'), ('Speed (knots)','@speed'),
            ('Course over Ground (degrees)','@course'), ('Heading (degrees)','@heading'), 
            ('Coordinates','(@lon, @lat)')]

data_points.create_canvas(title=f'Simple Visualization', tile_provider="CARTODBPOSITRON", sizing_mode='stretch_both', height=1000, tools="pan, box_zoom, lasso_select, wheel_zoom, hover, save, reset")
circ = data_points.add_marker(marker='circle', size=10, color='royalblue', alpha=0.7, fill_alpha=0.5, muted_alpha=0, legend_label=f'Vessel GPS Locations')
data_points.add_hover_tooltips(tooltips)
data_points.add_lasso_select()


columns = [
        bkhm.TableColumn(field="t", title="Timestamp"),
        bkhm.TableColumn(field="vessel_id", title="Vessel ID"),
        bkhm.TableColumn(field="speed", title="Speed (knots)"),
        bkhm.TableColumn(field="heading", title="Heading"),
        bkhm.TableColumn(field="lon", title="Longitude"),
        bkhm.TableColumn(field="lat", title="Latitude"),
        bkhm.TableColumn(field="velocity", title="Velocity"),
        bkhm.TableColumn(field="course", title="COG")
]
# data_table = bkhm.DataTable(source=data_points.source, columns=columns, width=400, height=280, sizing_mode='stretch_width')
data_table = bkhm.DataTable(source=data_points.source, columns=columns, width=400, height=400, sizing_mode='stretch_both')


### Camera, Lights, Action
data_points.figure.legend.location = "top_left"
data_points.figure.legend.click_policy = "mute"
data_points.figure.toolbar.active_scroll = data_points.figure.select_one(bkhm.WheelZoomTool)


#data_points.show_figures([[data_points.figure, data_table], [None, None]], notebook=True)

data_points.show_figures(
    figures=[data_points.figure, data_table],
    ncols=2,
    notebook=True,
    sizing_mode='stretch_both'
)
# Out:
# 2025-12-14 23:50:58.868 | INFO     | st_visions.visualization.st_visualizer:__init__:84 - VISIONS instance initialized with limit=5000, target_crs=3857
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d30064d9-f9ba-433f-86df-b0195d7fc035">Loading BokehJS ...</span>
#     </div>
# <script id="b7887899-5005-49d3-88b1-50111fe4e82c">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57724/autoload.js?bokeh-autoload-element=b7887899-5005-49d3-88b1-50111fe4e82c&bokeh-absolute-url=http://localhost:57724&resources=none", true);
#     xhr.withCredentials = false;
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
